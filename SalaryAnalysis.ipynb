# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
path=r"D:\Computer Science\Artifical Intelligence\Datasets\DataAnalyst"

# %%
#data=pd.read_csv(path+"\\usa-2016-presidential-election-by-county.csv", sep=';')
#data=pd.read_csv(r"D:\Computer Science\Artifical Intelligence\Datasets\DataAnalyst"+"\\DataAnalysis.csv")

# %%
data=pd.read_csv(path+"\\DataScientist.csv")

# %%
data
# Out:
#       Unnamed: 0  index                                          Job Title  \
# 0              0      0                              Senior Data Scientist
# 1              1      1                  Data Scientist, Product Analytics
# 2              2      2                               Data Science Manager
# 3              3      3                                       Data Analyst
# 4              4      4                             Director, Data Science
# ...          ...    ...                                                ...
# 3904        3904   4375                                  AWS Data Engineer
# 3905        3905   4376                              Data Analyst â Junior
# 3906        3906   4377                   Security Analytics Data Engineer
# 3907        3907   4378                   Security Analytics Data Engineer
# 3908        3908   4379  Patient Safety Physician or Safety Scientist -...
#
#                    Salary Estimate  \
# ...

# %% [markdown]
# ### Splitting salary column

# %%
def salary_split(data,index):
    list_min=[]
    list_max=[]
    for i in data.iloc[:,3]:
        if(i[12:16]=="Hour"):
            mi=i.split("-")[0][1:3]
            ma=i.split("-")[1].split(" ")[0][1:3]
            mi=int(mi)*40*4*12/1000
            ma=int(ma)*40*4*12/1000
        else:
            mi=i.split("-")[0].split("$")[1].split("K")[0]
            ma=i.split("-")[1].split("$")[1].split("K")[0]
        list_min.append(int(mi))
        list_max.append(int(ma))
    return list_min,list_max

# %%
list1,list2=salary_split(data,3)
data["salary_min"]=list1
data["salary_max"]=list2

# %%
data.describe()
# Out:
#         Unnamed: 0        index       Rating      Founded   salary_min  \
# count  3909.000000  3909.000000  3909.000000  3909.000000  3909.000000
# mean   1954.000000  2167.446662     3.283576  1479.154771    82.015093
# std    1128.575429  1247.657849     1.575749   855.750138    34.173604
# min       0.000000     0.000000    -1.000000    -1.000000    12.000000
# 25%     977.000000  1121.000000     3.200000  1625.000000    52.000000
# 50%    1954.000000  2161.000000     3.700000  1976.000000    76.000000
# 75%    2931.000000  3249.000000     4.100000  2002.000000   110.000000
# max    3908.000000  4379.000000     5.000000  2020.000000   200.000000
#
#         salary_max
# count  3909.000000
# mean    133.996163
# std      44.721334
# min      49.000000
# 25%      97.000000
# 50%     129.000000
# 75%     165.000000
# max     254.000000

# %%
data[data["salary_min"]>=200]
# Out:
#       Unnamed: 0  index                                          Job Title  \
# 2980        2980   3303                      Diagnostic Research Scientist
# 2981        2981   3304                                       Data Analyst
# 2982        2982   3305                             Senior HR Data Analyst
# 2983        2983   3306    Machine Learning Engineer, TikTok Ads Integrity
# 2984        2984   3307                                       Data Analyst
# 2985        2985   3308  Quantum Data Scientist (Industrial-Process sec...
# 2986        2986   3309                                Staff Data Engineer
# 2987        2987   3310                              Senior Data Scientist
# 2988        2988   3312  Marketing Data Scientist, gTech Professional S...
# 2989        2989   3313         Data Scientist, Ad Platforms/Data Insights
# 2990        2990   3314                                 Research Scientist
# ...

# %% [markdown]
# ## BivariateAnalysis

# %%
plt.plot(data["Rating"],data["salary_min"],"ro")

# %%
plt.plot(data["Founded"],data["Rating"],'bo')

# %% [markdown]
# ## Univariate Analysis

# %%
sns.distplot(data["Rating"])
# Out:
# <AxesSubplot:xlabel='Rating'>

# %%
sns.distplot(data["salary_min"])
# Out:
# <AxesSubplot:xlabel='salary_min'>

# %%
sns.distplot(data["salary_max"])
# Out:
# <AxesSubplot:xlabel='salary_max'>
